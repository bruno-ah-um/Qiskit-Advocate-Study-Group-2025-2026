# %% [markdown]
# **Reference:**
#
# Dancing with Qubits from Bob Sutor
#
# https://github.com/TMuehge/Qiskit-Advocate-Study-Group-2025-2026/blob/main/Material/DancingwithQubits.pdf

# %% [markdown]
# # One Qubit

# %% [markdown]
# ![image.png](attachment:f9fad9b7-18bb-4e54-955c-da1a2571db29.png)

# %% [markdown]
# ### Classical bit versus quantum bit

# %% [markdown]
# ![image.png](attachment:3a20f05c-0914-41b8-a9e4-8abc768cafa2.png)

# %% [markdown]
# ![image.png](attachment:5252f4a5-3025-45de-86d9-4cf5e20009b7.png)

# %% [markdown]
# ![image.png](attachment:dffbefdf-d6f7-4ede-892a-30e329a5f9be.png)

# %% [markdown]
# ![image.png](attachment:0f4bc6ee-90c2-4d68-916a-8b1558044ba2.png)

# %% [markdown]
# ![image.png](attachment:818f157c-74dc-44e4-a296-0f9798a89bc9.png)

# %% [markdown]
# # The Bloch Sphere

# %% [markdown]
# ![image.png](attachment:d19659b8-97a9-451b-8c02-e70909b1e853.png)

# %% [markdown]
# ![image.png](attachment:f598baa3-be26-4cf0-9abf-d70da01881d2.png)

# %% [markdown]
# ![image.png](attachment:5969d3d3-31d4-4795-937f-3e8d7d1a9e48.png)

# %% [markdown]
# ![image.png](attachment:9e14c988-1d9a-44cc-ade9-49d174cec55d.png)

# %% [markdown]
# ![image.png](attachment:69779c07-7041-4d3e-be17-30d80be2e703.png)

# %% [markdown]
# ![image.png](attachment:b25d0752-acf8-4c83-a538-054c886e6023.png)

# %% [markdown]
# # Gates:

# %% [markdown]
# ## Professor Hadamard meet Professor Pauli

# %% [markdown]
# ### The quantum X gate

# %% [markdown]
# ![image.png](attachment:0cc92178-091f-49eb-b2bc-e37a9f228323.png)

# %% [markdown]
# ![image.png](attachment:0bf58e8a-6539-4402-83c8-46c91f77b0df.png)

# %% [markdown]
# ![image.png](attachment:6d1bdf80-64de-43c8-9876-e58514028c53.png)

# %% [markdown]
# ![image.png](attachment:875eeafe-7aaa-4886-99e4-86da76f4f202.png)

# %% [markdown]
# ![image.png](attachment:e1f4d6af-9cab-4c37-888a-eb9da39c14dd.png)

# %%
import qiskit
import matplotlib.pyplot as plt
import matplotlib.axes as axes
import numpy as np

from qiskit import ClassicalRegister, QuantumRegister, QuantumCircuit

# %%
qc = QuantumCircuit(1)
qc.x(0)  # Add X-gate to qubit 0
#qc.x(1)
qc.measure_all()
qc.draw("mpl")

# %%
import numpy as np

# Import Qiskit
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram, plot_state_city
import qiskit.quantum_info as qi

# %%
# Transpile for simulator
simulator = AerSimulator()
circ = transpile(qc, simulator)

# %%
# Run and get counts
result = simulator.run(circ).result()
counts = result.get_counts(circ)

print(counts)
# Out:
# {'1': 1024}

# %%
plot_histogram(counts, title='Simple Circuit')

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

# %%
qc = QuantumCircuit(1)
qc.x(0)
#qc.x(1)

state = Statevector(qc)
plot_bloch_multivector(state)

# %% [markdown]
# # The quantum H gate

# %% [markdown]
# ![image.png](attachment:05ec7efa-39b5-46a7-8c7e-6df5e19aa577.png)

# %%
qc = QuantumCircuit(1)
qc.h(0)  # Add H-gate to qubit 0
#qc.x(1)
qc.measure_all()
qc.draw("mpl")

# %%
# Transpile for simulator
simulator = AerSimulator()
circ = transpile(qc, simulator)

# %%
# Run and get counts
result = simulator.run(circ).result()
counts = result.get_counts(circ)

print(counts)
# Out:
# {'0': 532, '1': 492}

# %%
plot_histogram(counts, title='Simple Circuit')

# %%
qc = QuantumCircuit(1)
qc.h(0)  # Add H-gate to qubit 0

state = Statevector(qc)
plot_bloch_multivector(state)
